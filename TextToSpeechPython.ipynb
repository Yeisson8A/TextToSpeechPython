# %%
# !pip install gTTS

# %%
# !pip install google-generativeai

# %%
import google.generativeai as genai
from gtts import gTTS
from IPython.display import Audio

# %%
# Configuración del modelo
genai.configure(api_key= "xxxxxxxxxxx")
model = genai.GenerativeModel(model_name="models/gemini-1.5-flash", system_instruction="A partir de ahora las respuestas las vas a presentar en un texto largo como un articulo")

# %%
consulta = input("Ingrese su consulta: ")
response = model.generate_content(consulta)
respuesta = response.text
# Out:
# Ingrese su consulta: hablame de william shakespeare

# %%
print(respuesta)
# Out:
# ## William Shakespeare: El Inmortal Cisne de Avon
#
# William Shakespeare, un nombre que resuena a través de los siglos, trascendiendo las barreras del idioma y la cultura.  Considerado por muchos como el más grande escritor en lengua inglesa, su legado literario se extiende más allá de la simple admiración, convirtiéndose en un pilar fundamental de la literatura mundial y una fuente inagotable de inspiración para artistas, académicos y amantes del teatro.  Nacido en Stratford-upon-Avon, Inglaterra, alrededor de 1564, y fallecido en la misma ciudad en 1616, Shakespeare dejó tras de sí un corpus de obras que redefine la dramaturgia y la poesía.
#
# ...

# %%
tts = gTTS(respuesta, lang='es')
tts.save('1.wav')
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
